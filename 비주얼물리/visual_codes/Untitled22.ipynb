# %%
#Interpolation for imshow

# %%
import matplotlib.pyplot as plt
import numpy as np

methods = [None, 'none', 'nearest', 'bicubic', 'bessel', 'lanczos']
methods2 = 

np.random.seed(19680801)

grid = np.random.rand(4,4)

fig, axs = plt.subplots(nrows=2, ncols=3, figsize = (6,6), subplot_kw={'xticks' : [], 'yticks' :[]})

for ax, interp_method in zip(axs.flat, methods) :
    ax.imshow(grid, interpolation = interp_method)
    ax.set_title(str(interp_method))
    
    
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

methods = [None, 'none', 'nearest', 'bicubic', 'bessel', 'lanczos']
methods2 = []

np.random.seed(19680801)

grid = np.random.rand(4,4)

fig, axs = plt.subplots(nrows=2, ncols=3, figsize = (6,6), subplot_kw={'xticks' : [], 'yticks' :[]})

for ax, interp_method in zip(axs.flat, methods) :
    ax.imshow(grid, interpolation = interp_method)
    ax.set_title(str(interp_method))
    
    
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

fhand = open('dosinNR2000eps0.0006Shiftedpm3dFormat.dat')
for line in fhand :
    datas = line.split(' ')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-60-ba3a8e000bbc> in <module>()
#       2 import numpy as np
#       3
# ----> 4 fhand = open('dosinNR2000eps0.0006Shiftedpm3dFormat.dat')
#       5 for line in fhand :
#       6     datas = line.split(' ')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'dosinNR2000eps0.0006Shiftedpm3dFormat.dat'

# %%
#import os
#os.chdir("/home/2015/2015550024/download/")

from scipy.interpolate import griddata

#Either one of these
z = np.loadtxt("dosinNR2000eps0.0006Shiftedpm3dFormat.dat", usecols=[0,1,2], unpack=True)
#z= np.genfromtxt("dosinNR2000eps0.0006Shiftedpm3dFormat.dat")

print(z)

x=np.arange(-0.3, 0.3, 0.0005)
y=np.arange(0,2.6,0.01)

zgridded = griddata((z[0], z[1]), z[2], (x[None,:], y[:,None]),method='cubic')

print(zgridded)  

#plt.figure(figsize=(20,10))

from matplotlib.pyplot import imshow
imshow(zgridded, origin="lower", extent=[-0.3,0.3, 0, 2.6])

plt.show()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-94-9f935a666fc6> in <module>()
#       5
#       6 #Either one of these
# ----> 7 z = np.loadtxt("dosinNR2000eps0.0006Shiftedpm3dFormat.dat", usecols=[0,1,2], unpack=True)
#       8 #z= np.genfromtxt("dosinNR2000eps0.0006Shiftedpm3dFormat.dat")
#       9
#
# ~/anaconda3/lib/python3.6/site-packages/numpy/lib/npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding)
#     915             fname = str(fname)
#     916         if _is_string_like(fname):
# --> 917             fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#     918             fencoding = getattr(fh, 'encoding', 'latin1')
#     919             fh = iter(fh)
#
# ~/anaconda3/lib/python3.6/site-packages/numpy/lib/_datasource.py in open(path, mode, destpath, encoding, newline)
#     258
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

data = np.genfromtxt("generate.spectral")

x=data[:,0]
y=data[:,1]*3.0
z=data[:,2]

plt.scatter(x,y,c=z)

plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
ux = np.unique(x); uy = np.unique(y)
Z = z.reshape(len(ux), len(uy)).T

dx = np.diff(ux[:,2])[0]; dy = np.diff(uy[:2])[0]
ext = [ux.min()-dx/2, ux.max()+dx/2.,uy.min()-dy/2., uy.max()+dy/2.]

plt.imshow(h.T, extent=ext, aspect="auto", cmap="magma")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-84-9203fdf013ad> in <module>()
#       2 Z = z.reshape(len(ux), len(uy)).T
#       3
# ----> 4 dx = np.diff(ux[:,2])[0]; dy = np.diff(uy[:2])[0]
#       5 ext = [ux.min()-dx/2, ux.max()+dx/2.,uy.min()-dy/2., uy.max()+dy/2.]
#       6
#
# IndexError: too many indices for array

# %%
import numpy as np

x_data = np.linspace(-5, 5, num=50)
y_data = np.sin(1.5*x_data) + np.random.normal(size=50)

plt.scatter(x_data, y_data)
plt.show()

# %%
from scipy import optimize
def test_func(x, a, b) :
    return a * np.sin(b * x)

params, params_covariance = optimize.curve_fit(test_func, x_data, y_data, p0=[2,2],)


print(params_convariance)
print(params)

plt.scatter(x_data, y_data, label='Data')

plt.plot(x_data, test_func(x_data, params[0], params[1]), laber='Filt')

plt.legend(loc='best')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-104-b88cb0cf8aba> in <module>()
#       6
#       7
# ----> 8 print(params_convariance)
#       9 print(params)
#      10
#
# NameError: name 'params_convariance' is not defined
