# %%
from vpython import*
from random import *
ballBig = sphere(pos = vector(0,0,0), radius = 100, color = color.red, opacity=0.5 )
ballmid = sphere(pos = vector(0,0,0), radius = 50, color = color.blue )
ball1 = sphere(pos = vector(0,70,0), radius = 10, color = color.green )
ball2 = sphere(pos = vector(70,0,0), radius = 10, color = color.green)
ball3 = sphere(pos = vector(0,0,70), radius = 10, color = color.green )
ball4 = sphere(pos = vector(60,60,0), radius = 10, color = color.green )
ball5 = sphere(pos = vector(0,60,60), radius = 10, color = color.green )
ball6 = sphere(pos = vector(60,0,60), radius = 10, color = color.green )
ball7 = sphere(pos = vector(-70,0,0), radius = 10, color = color.green )
ball8 = sphere(pos = vector(0,-70,0), radius = 10, color = color.green )

balls = [ballBig, ballmid, ball1, ball2, ball3, ball4, ball5, ball6, ball7, ball8]
deltat = 0.005
t = 0

for ball in balls :

    ball.velocity = vector(randint(1, 3),randint(1, 6),randint(1, 6))
    print(ball.velocity)
ballBig.velocity = vector(0,0,0)

while 1 :
    rate(500)
    for ball in balls :
        for otherballs in balls :
            if abs(ball.pos.x-otherballs.pos.x) <= ball.radius+otherballs.radius :
                ball.velocity.x = -otherballs.velocity.x
                otherballs.velocity.x = -ball.velocity.x
            if abs(ball.pos.y-otherballs.pos.y) <= ball.radius+otherballs.radius :
                ball.velocity.y = -otherballs.velocity.y
                otherballs.velocity.y = -ball.velocity.y
            if abs(ball.pos.z-otherballs.pos.z) <= ball.radius+otherballs.radius :
                ball.velocity.z = -otherballs.velocity.z  
                otherballs.velocity.z = -ball.velocity.z
            ball.pos = ball.pos + ball.velocity*deltat
            t = t+deltat
# Out:
# <div id="glowscript" class="glowscript"></div>

# %%
import re
dic = {}
a = 'sakaiproject'
print('I will print the domains include ' +a)
fhand = open('mboxshort.txt')
for line in fhand :
    line = line.rstrip()
    emails = re.findall('\w+@(\S+[a-z])',line)
    for email in emails :
        if a in email :
            print(line)
            print(emails)
# Out:
# I will print the domains include sakaiproject
# Return-Path: <postmaster@collab.sakaiproject.org>
# ['collab.sakaiproject.org']
#           for <source@collab.sakaiproject.org>;
# ['collab.sakaiproject.org']
# 	for <source@collab.sakaiproject.org>; Sat,  5 Jan 2008 14:13:33 +0000 (GMT)
# ['collab.sakaiproject.org']
# 	for <source@collab.sakaiproject.org>; Sat, 5 Jan 2008 09:12:19 -0500
# ['collab.sakaiproject.org']
# 	for source@collab.sakaiproject.org; Sat, 5 Jan 2008 09:12:18 -0500
# ['collab.sakaiproject.org']
# To: source@collab.sakaiproject.org
# ['collab.sakaiproject.org']
# Return-Path: <postmaster@collab.sakaiproject.org>
# ['collab.sakaiproject.org']
#           for <source@collab.sakaiproject.org>;
# ['collab.sakaiproject.org']
# 	for <source@collab.sakaiproject.org>; Fri,  4 Jan 2008 23:10:10 +0000 (GMT)
# ['collab.sakaiproject.org']
# 	for <source@collab.sakaiproject.org>; Fri, 4 Jan 2008 18:08:57 -0500
# ['collab.sakaiproject.org']
# ...
